# %% [markdown]
# **MACHINE LEARNING FEBRUARY PROJECT**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/arib168/data/main/50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.head()
# Out:
#          rnd  Administration         ms       State     Profit
# 0  165349.20       136897.80  471784.10    New York  192261.83
# 1  162597.70       151377.59  443898.53  California  191792.06
# 2  153441.51       101145.55  407934.54     Florida  191050.39
# 3  144372.41       118671.85  383199.62    New York  182901.99
# 4  142107.34        91391.77  366168.42     Florida  166187.94

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB
# None

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
print(df.shape)
print(df.size)
# Out:
# (50, 5)
# 250

# %%
df = df.rename(columns={"R&D Spend":"R&D_Spend"}) #renaming 
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-729e78605daf> in <module>()
# ----> 1 df = df.rename(columns={"R&D Spend":"R&D_Spend"}) #renaming
#       2 df.head()
#
# NameError: name 'df' is not defined

# %%
x = pd.pivot_table(data=df,index = ['State']) #mean of the values of the states
x
# Out:
#             Administration  Marketing Spend         Profit           rnd
# State
# California   120746.507059    182540.929412  103905.175294  64657.674118
# Florida      121768.897500    247323.551250  118774.024375  80724.016250
# New York     121543.470588    205346.015882  113756.446471  76195.062353

# %%
fname = df.State.unique()
fname
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
fsize = df.groupby('State',sort=False).size() #count of every state in column
fsize
# Out:
# State
# New York      17
# California    17
# Florida       16
# dtype: int64

# %%
#Number of times states has been mentioned 
plt.bar(fname,fsize,color='b''y''k')
plt.show()
#New york and California has most startups
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.

# %%
df.head()
# Out:
#          rnd  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
import seaborn as sns

# %%
x
# Out:
#             Administration  Marketing Spend         Profit           rnd
# State
# California   120746.507059    182540.929412  103905.175294  64657.674118
# Florida      121768.897500    247323.551250  118774.024375  80724.016250
# New York     121543.470588    205346.015882  113756.446471  76195.062353

# %%
df.head()
# Out:
#          rnd  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.describe()
# Out:
#                  rnd  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df.plot.box();

# %%
bp = df.boxplot(by="State")
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# ...

# %%
#Data of Research and development
states = df.State
r = df.rnd
plt.scatter(states,r)

# %%
#Research and development
print(x)
sns.barplot(x=df['State'],y=df['rnd'])
plt.show()
# Out:
#             Administration         Profit             ms           rnd
# State
# California   120746.507059  103905.175294  182540.929412  64657.674118
# Florida      121768.897500  118774.024375  247323.551250  80724.016250
# New York     121543.470588  113756.446471  205346.015882  76195.062353

# %%
sns.distplot(df['rnd'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Data of marketing spend
df = df.rename(columns={"Marketing Spend":"ms"}) #renaming 


m = df.ms
plt.scatter(states,m)

# %%
#marketing spend(ms)
print(x)
sns.barplot(x=df['State'],y=df['ms'])
plt.show()
# Out:
#             Administration         Profit             ms           rnd
# State
# California   120746.507059  103905.175294  182540.929412  64657.674118
# Florida      121768.897500  118774.024375  247323.551250  80724.016250
# New York     121543.470588  113756.446471  205346.015882  76195.062353

# %%
sns.distplot(df['ms'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Data of Administration
ad = df.Administration
plt.scatter(states,ad)

# %%
#Administration
sns.barplot(x=df['State'],y=df['Administration'])
plt.show()

# %%
sns.distplot(df['Administration'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Data of profit
pr = df.Administration
plt.scatter(states,pr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6fe721969c50> in <module>()
#       1 #Data of profit
# ----> 2 pr = df.Administration
#       3 plt.scatter(states,pr)
#
# NameError: name 'df' is not defined

# %%
#profit
sns.barplot(x=df['State'],y=df['Profit'])
plt.show()

# %%
sns.distplot(df['Profit'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#LINEAR REGRESSION

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rnd              50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df = df.select_dtypes(include = ['int64','float64'])
df.head()
# Out:
#          rnd  Administration  Marketing Spend     Profit
# 0  165349.20       136897.80        471784.10  192261.83
# 1  162597.70       151377.59        443898.53  191792.06
# 2  153441.51       101145.55        407934.54  191050.39
# 3  144372.41       118671.85        383199.62  182901.99
# 4  142107.34        91391.77        366168.42  166187.94

# %%
df.shape
# Out:
# (50, 4)

# %%
x=df.iloc[:,0:3]
y=df.iloc[:,-1]
print(x.head())
# Out:
#          rnd  Administration  Marketing Spend
# 0  165349.20       136897.80        471784.10
# 1  162597.70       151377.59        443898.53
# 2  153441.51       101145.55        407934.54
# 3  144372.41       118671.85        383199.62
# 4  142107.34        91391.77        366168.42

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.19, random_state = 9)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (40, 3)
# (10, 3)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_test
# Out:
# 21    111313.02
# 37     89949.14
# 2     191050.39
# 14    132602.65
# 44     65200.33
# 7     155752.60
# 15    129917.04
# 20    118474.03
# 32     97427.84
# 25    107404.34
# Name: Profit, dtype: float64

# %%
y_test
# Out:
# 21    111313.02
# 37     89949.14
# 2     191050.39
# 14    132602.65
# 44     65200.33
# 7     155752.60
# 15    129917.04
# 20    118474.03
# 32     97427.84
# 25    107404.34
# Name: Profit, dtype: float64

# %%
df1 = pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
df1
# Out:
#        Actual      Predicted
# 21  111313.02  119107.803941
# 37   89949.14   87833.217611
# 2   191050.39  182904.645804
# 14  132602.65  151909.965319
# 44   65200.33   66129.345987
# 7   155752.60  162063.098870
# 15  129917.04  147433.954397
# 20  118474.03  117113.058637
# 32   97427.84  100104.914334
# 25  107404.34  103592.134753

# %%
df1.plot(kind='bar')

# %%
sns.regplot(x='Actual',y='Predicted',data = df1)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9220826064890046
